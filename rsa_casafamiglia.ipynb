# %%
from fpdf import FPDF

# Creazione del PDF
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()
pdf.set_font("Arial", size=10)

# Titolo
pdf.set_font("Arial", size=14, style='B')
pdf.cell(0, 10, "Confronto tra Casa Famiglia e RSA", ln=True, align='C')
pdf.ln(10)

# Testo della tabella
table_data = [
    ["Criterio/Ambito di Confronto", "Casa Famiglia (per ragazzi/ragazze disagiate)", "RSA (Residenza Sanitaria Assistenziale)"],
    ["Destinatari", "Minori in situazioni di disagio familiare, sociale o economico", "Anziani o persone con gravi problemi di salute o disabilità"],
    ["Finalità", "Fornire un ambiente familiare e supportivo per la crescita e l'autonomia", "Assicurare assistenza sanitaria e sociale continuativa"],
    ["Servizi Offerti", "Supporto educativo, psicologico, scolastico e ricreativo", "Assistenza medica, infermieristica, riabilitazione e cura"],
    ["Personale", "Educatori, psicologi, assistenti sociali", "Medici, infermieri, fisioterapisti, OSS (operatori sociosanitari)"],
    ["Durata della Permanenza", "Temporanea, fino al reinserimento in famiglia o autonomia raggiunta", "Generalmente a lungo termine o fino alla stabilizzazione della salute"],
    ["Struttura", "Ambiente familiare, simile a una casa", "Struttura istituzionale con camere, ambulatori e aree comuni"],
    ["Normativa di Riferimento", "Leggi regionali e nazionali sui servizi sociali e protezione dei minori", "Norme sanitarie e sociali regionali, accreditamenti nazionali"],
    ["Gestione", "Solitamente enti non profit o cooperative sociali", "Può essere pubblica, privata o convenzionata"],
    ["Modalità di Accesso", "Segnalazione da parte dei servizi sociali, scuole, o decisione del tribunale per i minori", "Richiesta medica, valutazione dell'unità geriatrica o dell'ASL competente"],
    ["Attività durante la Permanenza", "Studio, laboratori creativi, sport, attività educative, supporto psicologico", "Terapie riabilitative, attività ricreative, incontri sociali, assistenza quotidiana"],
    ["Interazione con i Familiari", "Facilitata e incoraggiata attraverso visite, colloqui, e percorsi di reinserimento", "Visite regolate da orari, supporto per mantenere relazioni familiari"],
    ["Controlli durante la Permanenza", "Monitoraggio educativo, valutazioni psicologiche e scolastiche periodiche", "Controlli clinici, valutazioni periodiche del piano di cura"],
    ["Interazione tra Ospiti e Personale Sociale/Sanitario", "Rapporto stretto con educatori e assistenti sociali per promuovere fiducia e sviluppo personale", "Relazione con personale sanitario per supporto quotidiano e monitoraggio continuo"],
    ["Visite Mediche", "Non regolari, solo se necessarie, con accompagnamento", "Regolari e programmate, incluse visite specialistiche"],
    ["Controllo degli Ospiti", "Supervisione costante per garantire sicurezza e benessere", "Controllo giornaliero da parte del personale infermieristico e OSS"],
    ["Verifiche durante la Permanenza", "Verifiche periodiche da parte dei servizi sociali e degli enti preposti", "Ispezioni interne ed esterne per garantire il rispetto degli standard di cura e sicurezza"]
]

# Dimensioni delle colonne
col_widths = [60, 65, 65]

# Creazione della tabella
pdf.set_font("Arial", size=9)
for row in table_data:
    for i, item in enumerate(row):
        pdf.cell(col_widths[i], 6, item, border=1, ln=0, align='L')
    pdf.ln()

# Salvataggio del PDF
file_path = "Confronto_Casa_Famiglia_RSA.pdf"
pdf.output(file_path)

file_path
# Out:
# 'Confronto_Casa_Famiglia_RSA.pdf'

# %%
from fpdf import FPDF

# Creazione del PDF
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()
pdf.set_font("Arial", size=10)

# Titolo
pdf.set_font("Arial", size=14, style='B')
pdf.cell(0, 10, "Confronto tra Casa Famiglia e RSA", ln=True, align='C')
pdf.ln(10)

# Testo della tabella
table_data = [
    ["Criterio/Ambito di Confronto", "Casa Famiglia (per ragazzi/ragazze disagiate)", "RSA (Residenza Sanitaria Assistenziale)"],
    ["Destinatari", "Minori in situazioni di disagio familiare, sociale o economico", "Anziani o persone con gravi problemi di salute o disabilità"],
    ["Finalità", "Fornire un ambiente familiare e supportivo per la crescita e l'autonomia", "Assicurare assistenza sanitaria e sociale continuativa"],
    ["Servizi Offerti", "Supporto educativo, psicologico, scolastico e ricreativo", "Assistenza medica, infermieristica, riabilitazione e cura"],
    ["Personale", "Educatori, psicologi, assistenti sociali", "Medici, infermieri, fisioterapisti, OSS (operatori sociosanitari)"],
    ["Durata della Permanenza", "Temporanea, fino al reinserimento in famiglia o autonomia raggiunta", "Generalmente a lungo termine o fino alla stabilizzazione della salute"],
    ["Struttura", "Ambiente familiare, simile a una casa", "Struttura istituzionale con camere, ambulatori e aree comuni"],
    ["Normativa di Riferimento", "Leggi regionali e nazionali sui servizi sociali e protezione dei minori", "Norme sanitarie e sociali regionali, accreditamenti nazionali"],
    ["Gestione", "Solitamente enti non profit o cooperative sociali", "Può essere pubblica, privata o convenzionata"],
    ["Modalità di Accesso", "Segnalazione da parte dei servizi sociali, scuole, o decisione del tribunale per i minori", "Richiesta medica, valutazione dell'unità geriatrica o dell'ASL competente"],
    ["Attività durante la Permanenza", "Studio, laboratori creativi, sport, attività educative, supporto psicologico", "Terapie riabilitative, attività ricreative, incontri sociali, assistenza quotidiana"],
    ["Interazione con i Familiari", "Facilitata e incoraggiata attraverso visite, colloqui, e percorsi di reinserimento", "Visite regolate da orari, supporto per mantenere relazioni familiari"],
    ["Controlli durante la Permanenza", "Monitoraggio educativo, valutazioni psicologiche e scolastiche periodiche", "Controlli clinici, valutazioni periodiche del piano di cura"],
    ["Interazione tra Ospiti e Personale Sociale/Sanitario", "Rapporto stretto con educatori e assistenti sociali per promuovere fiducia e sviluppo personale", "Relazione con personale sanitario per supporto quotidiano e monitoraggio continuo"],
    ["Visite Mediche", "Non regolari, solo se necessarie, con accompagnamento", "Regolari e programmate, incluse visite specialistiche"],
    ["Controllo degli Ospiti", "Supervisione costante per garantire sicurezza e benessere", "Controllo giornaliero da parte del personale infermieristico e OSS"],
    ["Verifiche durante la Permanenza", "Verifiche periodiche da parte dei servizi sociali e degli enti preposti", "Ispezioni interne ed esterne per garantire il rispetto degli standard di cura e sicurezza"]
]

# Dimensioni delle colonne
col_widths = [60, 65, 65]
line_height = 5

# Creazione della tabella
pdf.set_font("Arial", size=9)

for row in table_data:
    # Calcolare l'altezza massima della riga in base al contenuto di ogni cella
    max_lines = 0
    for i, item in enumerate(row):
        # Dividere il testo in righe rispetto alla larghezza della colonna
        lines = pdf.multi_cell(col_widths[i], line_height, item, border=0, split_only=True)
        max_lines = max(max_lines, len(lines))
    
    row_height = max_lines * line_height

    # Scrivere ogni cella della riga con l'altezza uniforme
    for i, item in enumerate(row):
        x = pdf.get_x()
        y = pdf.get_y()
        pdf.multi_cell(col_widths[i], line_height, item, border=1, align='L')
        pdf.set_xy(x + col_widths[i], y)
    
    # Passare alla riga successiva
    pdf.ln(row_height)

# Salvataggio del PDF
file_path = "Confronto_Casa_Famiglia_RSA.pdf"
pdf.output(file_path)

file_path
# Out:
# 'Confronto_Casa_Famiglia_RSA.pdf'

# %%
from fpdf import FPDF

# Creazione del PDF
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()
pdf.set_font("Arial", size=10)

# Titolo
pdf.set_font("Arial", size=14, style='B')
pdf.cell(0, 10, "Confronto tra Casa Famiglia e RSA", ln=True, align='C')
pdf.ln(10)

# Testo della tabella
table_data = [
    ["Criterio/Ambito di Confronto", "Casa Famiglia (per ragazzi/ragazze disagiate)", "RSA (Residenza Sanitaria Assistenziale)"],
    ["Destinatari", "Minori in situazioni di disagio familiare, sociale o economico", "Anziani o persone con gravi problemi di salute o disabilità"],
    ["Finalità", "Fornire un ambiente familiare e supportivo per la crescita e l'autonomia", "Assicurare assistenza sanitaria e sociale continuativa"],
    ["Servizi Offerti", "Supporto educativo, psicologico, scolastico e ricreativo", "Assistenza medica, infermieristica, riabilitazione e cura"],
    ["Personale", "Educatori, psicologi, assistenti sociali", "Medici, infermieri, fisioterapisti, OSS (operatori sociosanitari)"],
    ["Durata della Permanenza", "Temporanea, fino al reinserimento in famiglia o autonomia raggiunta", "Generalmente a lungo termine o fino alla stabilizzazione della salute"],
    ["Struttura", "Ambiente familiare, simile a una casa", "Struttura istituzionale con camere, ambulatori e aree comuni"],
    ["Normativa di Riferimento", "Leggi regionali e nazionali sui servizi sociali e protezione dei minori", "Norme sanitarie e sociali regionali, accreditamenti nazionali"],
    ["Gestione", "Solitamente enti non profit o cooperative sociali", "Può essere pubblica, privata o convenzionata"],
    ["Modalità di Accesso", "Segnalazione da parte dei servizi sociali, scuole, o decisione del tribunale per i minori", "Richiesta medica, valutazione dell'unità geriatrica o dell'ASL competente"],
    ["Attività durante la Permanenza", "Studio, laboratori creativi, sport, attività educative, supporto psicologico", "Terapie riabilitative, attività ricreative, incontri sociali, assistenza quotidiana"],
    ["Interazione con i Familiari", "Facilitata e incoraggiata attraverso visite, colloqui, e percorsi di reinserimento", "Visite regolate da orari, supporto per mantenere relazioni familiari"],
    ["Controlli durante la Permanenza", "Monitoraggio educativo, valutazioni psicologiche e scolastiche periodiche", "Controlli clinici, valutazioni periodiche del piano di cura"],
    ["Interazione tra Ospiti e Personale Sociale/Sanitario", "Rapporto stretto con educatori e assistenti sociali per promuovere fiducia e sviluppo personale", "Relazione con personale sanitario per supporto quotidiano e monitoraggio continuo"],
    ["Visite Mediche", "Non regolari, solo se necessarie, con accompagnamento", "Regolari e programmate, incluse visite specialistiche"],
    ["Controllo degli Ospiti", "Supervisione costante per garantire sicurezza e benessere", "Controllo giornaliero da parte del personale infermieristico e OSS"],
    ["Verifiche durante la Permanenza", "Verifiche periodiche da parte dei servizi sociali e degli enti preposti", "Ispezioni interne ed esterne per garantire il rispetto degli standard di cura e sicurezza"]
]

# Dimensioni delle colonne
col_widths = [60, 65, 65]
line_height = 5

# Celle unificate da considerare
merge_columns = [0]  # Indice delle colonne da unire

# Creazione della tabella
pdf.set_font("Arial", size=9)
row_heights = []

# Prima calcolo l'altezza di ogni riga
for row in table_data:
    max_lines = 0
    for i, item in enumerate(row):
        # Calcolo righe necessarie per ogni cella
        lines = pdf.multi_cell(col_widths[i], line_height, item, border=0, split_only=True)
        max_lines = max(max_lines, len(lines))
    row_heights.append(max_lines * line_height)

# Creazione delle celle con unione verticale
start_y = pdf.get_y()
for row_idx, row in enumerate(table_data):
    max_height = row_heights[row_idx]
    for col_idx, item in enumerate(row):
        if col_idx in merge_columns and row_idx > 0:
            # Evita di ridisegnare celle unificate
            continue
        if col_idx in merge_columns:
            # Unire celle in verticale
            total_height = sum(row_heights[row_idx:])
            pdf.multi_cell(col_widths[col_idx], total_height, item, border=1, align='L')
        else:
            x = pdf.get_x()
            y = pdf.get_y()
            pdf.multi_cell(col_widths[col_idx], line_height, item, border=1, align='L')
            pdf.set_xy(x + col_widths[col_idx], y)
    pdf.ln(max_height)

# Salvataggio del PDF
file_path = "Confronto_Casa_Famiglia_RSA_Unified.pdf"
pdf.output(file_path)

file_path
# Out:
# 'Confronto_Casa_Famiglia_RSA_Unified.pdf'

# %%
import pandas as pd

# Dati per la tabella
data = [
    ["Criterio/Ambito di Confronto", "Casa Famiglia (per ragazzi/ragazze disagiate)", "RSA (Residenza Sanitaria Assistenziale)"],
    ["Destinatari", "Minori in situazioni di disagio familiare, sociale o economico", "Anziani o persone con gravi problemi di salute o disabilità"],
    ["Finalità", "Fornire un ambiente familiare e supportivo per la crescita e l'autonomia", "Assicurare assistenza sanitaria e sociale continuativa"],
    ["Servizi Offerti", "Supporto educativo, psicologico, scolastico e ricreativo", "Assistenza medica, infermieristica, riabilitazione e cura"],
    ["Personale", "Educatori, psicologi, assistenti sociali", "Medici, infermieri, fisioterapisti, OSS (operatori sociosanitari)"],
    ["Durata della Permanenza", "Temporanea, fino al reinserimento in famiglia o autonomia raggiunta", "Generalmente a lungo termine o fino alla stabilizzazione della salute"],
    ["Struttura", "Ambiente familiare, simile a una casa", "Struttura istituzionale con camere, ambulatori e aree comuni"],
    ["Normativa di Riferimento", "Leggi regionali e nazionali sui servizi sociali e protezione dei minori", "Norme sanitarie e sociali regionali, accreditamenti nazionali"],
    ["Gestione", "Solitamente enti non profit o cooperative sociali", "Può essere pubblica, privata o convenzionata"],
    ["Modalità di Accesso", "Segnalazione da parte dei servizi sociali, scuole, o decisione del tribunale per i minori", "Richiesta medica, valutazione dell'unità geriatrica o dell'ASL competente"],
    ["Attività durante la Permanenza", "Studio, laboratori creativi, sport, attività educative, supporto psicologico", "Terapie riabilitative, attività ricreative, incontri sociali, assistenza quotidiana"],
    ["Interazione con i Familiari", "Facilitata e incoraggiata attraverso visite, colloqui, e percorsi di reinserimento", "Visite regolate da orari, supporto per mantenere relazioni familiari"],
    ["Controlli durante la Permanenza", "Monitoraggio educativo, valutazioni psicologiche e scolastiche periodiche", "Controlli clinici, valutazioni periodiche del piano di cura"],
    ["Interazione tra Ospiti e Personale Sociale/Sanitario", "Rapporto stretto con educatori e assistenti sociali per promuovere fiducia e sviluppo personale", "Relazione con personale sanitario per supporto quotidiano e monitoraggio continuo"],
    ["Visite Mediche", "Non regolari, solo se necessarie, con accompagnamento", "Regolari e programmate, incluse visite specialistiche"],
    ["Controllo degli Ospiti", "Supervisione costante per garantire sicurezza e benessere", "Controllo giornaliero da parte del personale infermieristico e OSS"],
    ["Verifiche durante la Permanenza", "Verifiche periodiche da parte dei servizi sociali e degli enti preposti", "Ispezioni interne ed esterne per garantire il rispetto degli standard di cura e sicurezza"]
]

# Creazione DataFrame
df = pd.DataFrame(data, columns=["Criterio/Ambito di Confronto", "Casa Famiglia", "RSA"])

# Salvataggio in un file Excel
file_path = "Confronto_Casa_Famiglia_RSA.xlsx"
df.to_excel(file_path, index=False)

file_path
# Out:
# 'Confronto_Casa_Famiglia_RSA.xlsx'
